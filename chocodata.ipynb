# %%
import requests
import time
import random
import bs4
import base64
import urllib.parse
import json
import os
import re

# %%
def is_blocked(html: str) -> bool:
    soup = bs4.BeautifulSoup(html, "html.parser")
    text = " ".join(soup.stripped_strings).lower()

    if soup.find(id="captcha-form"):
        return True

    if soup.select_one(
        ".g-recaptcha, iframe[src*='recaptcha'], script[src*='recaptcha']"
    ):
        return True

    if any(
        "/sorry/" in form.get("action", "").lower() for form in soup.find_all("form")
    ):
        return True

    return any(
        marker in text
        for marker in (
            "our systems have detected unusual traffic",
            "computer or network may be sending automated queries",
            "we can't process your request right now",
            "not a robot",
        )
    )


def fetch(url, max_retries=4):
    retry_reason = ""

    for attempt in range(max_retries + 1):
        try:
            response = requests.get(
                "https://api.chocodata.com/api/v1/universal/get?"
                "api_key=cd_live_yijfHmqUz2GHFrX21kVwtzkbKy2aNULL&parse=html&country=us"
                f"&url={urllib.parse.quote(url)}"
            )
            if response.status_code == 200:
                html = response.json()["html"]

                if not is_blocked(html):
                    return html
                else:
                    retry_reason = "block or captcha, "

            else:
                retry_reason = f"status = {response.status_code}, error = {response.json()["error"]}, "
        except requests.ConnectionError:
            retry_reason = "connection error, "
        except requests.Timeout:
            retry_reason = "timeout, "

        if attempt == max_retries:
            raise RuntimeError("Request failed or CAPTCHA persisted")

        print(f"{retry_reason}retry...")
        time.sleep(random.uniform(2, min(60, 2 ** (attempt + 2))))
    return ""

# %%
profile_soup = bs4.BeautifulSoup(
    fetch("https://scholar.google.com/citations?user=qHFA5z4AAAAJ&hl=en&pagesize=100"),
    "html.parser",
)

paper_list = [
    dict(
        {
            "year": row.select_one(".gsc_a_y").get_text(strip=True),
            "citation_url": urllib.parse.urljoin(
                "https://scholar.google.com",
                row.select_one(".gsc_a_at")["href"],
            ),
        }
    )
    for row in profile_soup.select(".gsc_a_tr")
]

print(len(paper_list))
paper_list
# Out:
# 57
# [{'year': '2023',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:Y0pCki6q_DkC'},
#  {'year': '2020',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:2osOgNQ5qMEC'},
#  {'year': '2020',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:bnK-pcrLprsC'},
#  {'year': '2020',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:Se3iqnhoufwC'},
#  {'year': '2019',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:IjCSPb-OGe4C'},
#  {'year': '2020',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:UebtZRa9Y70C'},
#  {'year': '2020',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:Tyk-4Ss8FVUC'},
#  {'year': '2020',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:8k81kl-MbHgC'},
#  {'year': '2021',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:MXK_kJrjxJIC'},
#  {'year': '2025',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:Z5m8FVwuT1cC'},
#  {'year': '2020',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:kNdYIx-mwKoC'},
#  {'year': '2021',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:9ZlFYXVOiuMC'},
#  {'year': '2019',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:YsMSGLbcyi4C'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:RHpTSmoSYBkC'},
#  {'year': '2023',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:ldfaerwXgEUC'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:GnPB-g6toBAC'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:RGFaLdJalmkC'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:4TOpqqG69KYC'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:TFP_iSt0sucC'},
#  {'year': '2021',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:KlAtU1dfN6UC'},
#  {'year': '2021',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:ULOm3_A8WrAC'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:BqipwSGYUEgC'},
#  {'year': '2019',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:zYLM7Y9cAGgC'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:nb7KW1ujOQ8C'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:HoB7MX3m0LUC'},
#  {'year': '2021',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:0EnyYjriUFMC'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:35N4QoGY0k4C'},
#  {'year': '2019',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:eQOLeE2rZwMC'},
#  {'year': '2020',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:LkGwnXOMwfcC'},
#  {'year': '2020',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:ufrVoPGSRksC'},
#  {'year': '2024',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:NaGl4SEjCO4C'},
#  {'year': '2023',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:dshw04ExmUIC'},
#  {'year': '2021',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:-FonjvnnhkoC'},
#  {'year': '2018',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:qjMakFHDy7sC'},
#  {'year': '2025',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:PoWvk5oyLR8C'},
#  {'year': '2024',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:geHnlv5EZngC'},
#  {'year': '2026',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:WZBGuue-350C'},
#  {'year': '2025',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:S16KYo8Pm5AC'},
#  {'year': '2025',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:foquWX3nUaYC'},
#  {'year': '2025',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:p2g8aNsByqUC'},
#  {'year': '2023',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:_xSYboBqXhAC'},
#  {'year': '2023',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:pyW8ca7W8N0C'},
#  {'year': '2026',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:oNZyr7d5Mn4C'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:J_g5lzvAfSwC'},
#  {'year': '2025',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:M7yex6snE4oC'},
#  {'year': '2025',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:4OULZ7Gr8RgC'},
#  {'year': '2018',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:d1gkVwhDpl0C'},
#  {'year': '2025',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:epqYDVWIO7EC'},
#  {'year': '2025',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:V3AGJWp-ZtQC'},
#  {'year': '2024',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:Tiz5es2fbqcC'},
#  {'year': '2024',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:yD5IFk8b50cC'},
#  {'year': '2024',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:tzM49s52ZIMC'},
#  {'year': '2026',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:HbR8gkJAVGIC'},
#  {'year': '2026',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:XoXfffV-tXoC'},
#  {'year': '2026',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:ruyezt5ZtCIC'},
#  {'year': '2026',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:q3CdL3IzO_QC'},
#  {'year': '2022',
#   'citation_url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=qHFA5z4AAAAJ&pagesize=100&citation_for_view=qHFA5z4AAAAJ:pqnbT2bcN3wC'}]

# %%
def parse_citation(html):
    soup = bs4.BeautifulSoup(html, "html.parser")

    title = soup.select_one("#gsc_oci_title")
    fields = {"title": title.get_text(" ", strip=True) if title else None}
    clusters = []

    for row in soup.select("div.gs_scl"):
        key = row.select_one(".gsc_oci_field")
        value = row.select_one(".gsc_oci_value")
        if not key or not value:
            continue

        name = key.get_text(" ", strip=True).lower()

        if name == "scholar articles":
            for snippet in value.select(".gsc_oci_merged_snippet"):
                link = snippet.select_one("a[href*='cluster=']")
                match = (
                    re.search(r"cluster=(\d+)", link.get("href", "")) if link else None
                )
                if match and match.group(1) not in clusters:
                    clusters.append(match.group(1))
        elif name != "total citations" and name != "description":
            fields[name] = value.get_text(" ", strip=True)

    return {**fields, "clusters": clusters}


for paper in paper_list:
    paper |= parse_citation(fetch(paper["citation_url"]))
    print(paper["title"], paper["clusters"])

with open("papers2.json", "w") as file:
    json.dump(paper_list, file, indent=4)
# Out:
# Stochastic distributed learning with gradient quantization and double-variance reduction ['10432066948921138844']
# Don’t jump through hoops and remove those loops: SVRG and Katyusha are better without the outer loop ['7006814588298832736']
# Acceleration for compressed gradient descent in distributed and federated optimization ['1371688885190462102']
# From local SGD to local fixed-point methods for federated learning ['15088076385024246021']
# RSN: randomized subspace Newton ['7373789986788030402']
# Optimal and practical algorithms for smooth and strongly convex decentralized optimization ['15665175903150090179']
# Revisiting stochastic extragradient ['8653605232017703121']
# block or captcha, retry...
# Linearly converging error compensated SGD ['9254067822190880000']
# A linearly convergent algorithm for decentralized optimization: Sending less bits for free! ['3790088210576421356']
# Understanding gradient orthogonalization for deep learning via non-euclidean trust-region optimization ['9464268600160663021']
# Accelerated methods for saddle-point problem ['9373209880233203502', '4686524615161672519']
# Lower bounds and optimal algorithms for smooth and strongly convex decentralized optimization over time-varying networks ['218386955491957145']
# Stochastic Newton and cubic Newton methods with simple local linear-quadratic rates ['3002705566416746554']
# Accelerated primal-dual gradient method for smooth and convex-concave saddle-point problems with bilinear coupling ['313086167555561841']
# Smooth monotone stochastic variational inequalities and saddle point problems: A survey ['6416508855679529689']
# The first optimal acceleration of high-order methods in smooth convex optimization ['12882769054337015160']
# Optimal gradient sliding and its application to optimal distributed optimization under similarity ['15617746434035789497']
# An optimal algorithm for strongly convex minimization under affine constraints ['15110157264304090339']
# Optimal algorithms for decentralized stochastic variational inequalities ['16974920721308888306']
# Decentralized distributed optimization for saddle point problems ['15155949253390165076']
# ADOM: accelerated decentralized optimization method for time-varying networks ['13055424477930940340']
# The first optimal algorithm for smooth and strongly-convex-strongly-concave minimax optimization ['6878778451294198426']
# Stochastic proximal Langevin algorithm: Potential splitting and nonasymptotic rates ['8964049524700423512']
# IntSGD: Adaptive floatless compression of stochastic gradients ['16969044896100418296', '15707566150174104807']
# Accelerated variance-reduced methods for saddle-point problems ['12130567569437016761', '14409392578980627652', '9962708434638871334', '1257530239269417616']
# Towards accelerated rates for distributed optimization over time-varying networks ['2324971111724151487', '15304990829005952707']
# Communication acceleration of local gradient methods via an accelerated primal-dual algorithm with an inexact prox ['10468598298336511368']
# Distributed fixed point methods with compressed iterates ['9469053425606975651']
# Fast linear convergence of randomized BFGS ['12043257693440176889']
# Variance reduced coordinate descent with acceleration: New method with a surprising application to finite-sum problems ['14069246331553141070']
# Decentralized saddle-point problems with different constants of strong convexity and strong concavity ['2159104910581211829']
# Decentralized convex optimization over time-varying graphs ['14256695056462406414']
# Near-optimal decentralized algorithms for saddle point problems over time-varying networks ['4252407442233130977', '11682401705022143728', '18367348657283013424']
# Stochastic spectral and conjugate descent methods ['15120261814030278283']
# Muon is provably faster with momentum variance reduction ['8842333574408060167']
# Lower Bounds and Optimal Algorithms for Non-Smooth Convex Decentralized Optimization over Time-Varying Networks ['11605182395180550612']
# Nesterov finds GRAAL: Optimal and adaptive gradient method for convex optimization ['7506260031426519626']
# block or captcha, retry...
# Non-euclidean sgd for structured optimization: Unified analysis and improved rates ['10610298617999658258']
# Near-optimal algorithm with complexity separation for strongly convex-strongly concave composite saddle point problems ['3365804316294644363', '6047283591819691195']
# Decentralized saddle point problems via non-Euclidean mirror prox ['13234451182204652906']
# Non-smooth setting of stochastic decentralized convex optimization problem over time-varying graphs ['3091891129863570914']
# Is consensus acceleration possible in decentralized optimization over slowly time-varying networks? ['9454741829138024660']
# Sgd with adaptive preconditioning: Unified analysis and momentum acceleration ['658499838430938452']
# On scaled methods for saddle point problems ['6878525993176263563']
# On Linear Convergence in Smooth Convex-Concave Bilinearly-Coupled Saddle-Point Optimization: Lower Bounds and Optimal Algorithms ['6229982026178002764', '1214191133118673585']
# An Optimal Algorithm for Strongly Convex Min-Min Optimization ['13821591043027385090', '13028606441871676013']
# A hypothesis about the rate of global convergence for optimal methods (Newton’s type) in smooth convex optimization ['3812646967675013786']
# On solving minimization and min-max problems by first-order methods with relative error in gradients ['10910203543962959848']
# Decentralized Optimization with Coupled Constraints ['18026434151566644045']
# Decentralized finite-sum optimization over time-varying networks ['9027699018424793418']
# Decentralized convex optimization on time-varying networks with application to Wasserstein barycenters ['3040641654477328482', '4942379545739387070']
# Convex-Concave Interpolation and Application of PEP to the Bilinear-Coupled Saddle Point Problem ['8894740852949274823']
# Optimal Projection-Free Adaptive SGD for Matrix Optimization ['9597637398750543612']
# Stronger constraints for smooth min-max games ['3379863577059025727', '8979664031721282505']
# On the complexity of decentralized optimization via global function parameters ['16285739136266099699']
# Stochastic Non-Smooth Convex Optimization with Unbounded Gradients ['4320678755420948797']
# Optimal Algorithms for Affinely Constrained, Distributed, Decentralized, Minimax, and High-Order Optimization Problems ['7226585304015966991']

# %% [markdown]
# # Clusters

# %%
with open("papers2.json", "r") as file:
    paper_list = json.load(file)

# %%
def load_clusters(cluster, max_pages=5, num=20):
    links = set()
    for i in range(max_pages):
        soup = bs4.BeautifulSoup(
            fetch(
                f"https://scholar.google.com/scholar?start={i * num}&num={num}&hl=en&cluster={cluster}"
            )
        )
        print(f"page {i+1}")
        for a in soup.select(".gs_r h3.gs_rt a[href]"):
            links.update([a["href"]])
            print(f"\t{a["href"]}")
        if not soup.select_one(".gs_ico_nav_next"):
            break

    return list(links)


load_clusters("10432066948921138844")
# Out:
# status = 502, error = target_unreachable, retry...

# %%
for paper in paper_list:
    clusters = ",".join(paper["clusters"])
    print(paper["title"], clusters)
    paper["links"] = load_clusters(clusters)

with open("papers_with_links.json", "w") as file:
    json.dump(paper_list, file, indent=4)
# Out:
# Stochastic distributed learning with gradient quantization and double-variance reduction 10432066948921138844
# status = 502, error = target_unreachable, retry...
# status = 502, error = target_unreachable, retry...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 4
#       2     clusters = ",".join(paper["clusters"])
#       3     print(paper["title"], clusters)
# ----> 4     paper["links"] = load_clusters(clusters)
#       6 with open("papers_with_links.json", "w") as file:
#       7     json.dump(paper_list, file, indent=4)
#
# Cell In[31], line 5, in load_clusters(cluster, max_pages, num)
#       2 links = set()
#       3 for i in range(max_pages):
#       4     soup = bs4.BeautifulSoup(
# ----> 5         fetch(
#       6             f"https://scholar.google.com/scholar?start={i * num}&num={num}&hl=en&cluster={cluster}"
#       7         )
#       8     )
#       9     print(f"page {i+1}")
#      10     for a in soup.select(".gs_r h3.gs_rt a[href]"):
#
# Cell In[32], line 58, in fetch(url, max_retries)
#      55         raise RuntimeError("Request failed or CAPTCHA persisted")
#      57     print(f"{retry_reason}retry...")
# ---> 58     time.sleep(random.uniform(2, min(60, 2 ** (attempt + 2))))
#      59 return ""
#
# KeyboardInterrupt:
