# %%
import requests
import os
import json


def serp(endpoint, params):
    url = f"https://api.justserpapi.com/api/v1/google/scholar/{endpoint}"
    headers = {"X-API-Key": os.environ["JUSTSERPAPI_KEY"]}
    response = requests.get(url, headers=headers, params=params)
    return response.json()

# %%
author = serp("author", {"author_id": "qHFA5z4AAAAJ", "results": 100, "language": "en"})

# %%
print(json.dumps(author, indent=4))
# Out:
# {
#     "code": 200,
#     "message": "success",
#     "data": {
#         "author": {
#             "name": "Dmitry Kovalev",
#             "affiliations": "Yandex",
#             "email": "Verified email at kaust.edu.sa - Homepage",
#             "interests": [
#                 {
#                     "title": "optimization",
#                     "link": "https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:optimization"
#                 },
#                 {
#                     "title": "machine learning",
#                     "link": "https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:machine_learning"
#                 }
#             ],
#             "thumbnail": "https://scholar.google.comhttps://scholar.googleusercontent.com/citations?view_op=view_photo&user=qHFA5z4AAAAJ&citpid=2"
#         },
#         "articles": [
#             {
# ...
